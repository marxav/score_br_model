# %%
import pandas as pd

# %%
df_logs = pd.read_csv('2024-06-09_19:05:57_tregor_2110_br_logs.csv', sep='\t')

# %%
df_logs
# Out:
#                                                    br  \
# 0   Eñvorennoù : geriadur Ernod 1927\nA-benn ar fi...
# 1    Goude pakañ e vez dispakañ d’ober, hag e-barz...
# 2    Un tamm levrig bihan eo 9 santimetr dre 13,5 ...
# 3          Bihan ne dalvez ket ez eo paour ha divalav
# 4    Ur bern gerioù a zo kouchet e-barzh, gerioù d...
# 5    Emile Ernault en doa desket brezhoneg e-unan ...
# 6    Heuilh a reas kentelioù Jozef Loth e Roazhon ...
# 7                            Ganet e oa ma zad e 1910
# 8    Tuet evel ma oa da zeskiñ yezhoù, e soñjas d’...
# 9    Setu profet al levr dezhañ hag eñ da studiañ ...
# 10   Mont a reas e vestr-studi da furchal e-barzh ...
# 11   Pa resevas e dad al lizher a-berzh ar skol e ...
# 12     Ha hemañ d’ar skolaj-lise da grozal d’ar rener
# 13   Plegañ a reas ar rener ha rentet e voe e levr...
# 14   Derc’hel a reas Jakez Konan neuze, da studïañ...
# 15   Ma welfec’h e petore stad truezus emañ ar ger...
# ...

# %%
df_res = pd.read_csv('2024-06-09_19:05:57_tregor_2110_br_res.csv', sep='\t')

# %%
df_res
# Out:
#               datetime                   model  mean   std  price  tokens
# 0  2024-06-09_19:05:57           gpt-3.5-turbo  0.83  0.22   0.05   60762
# 1  2024-06-09_19:05:57  gpt-4-turbo-2024-04-09  0.84  0.22   0.56   60572
