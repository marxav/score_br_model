# %%
import pandas as pd

# %%
df_logs = pd.read_csv('2024-06-09_18:49:56_samples_logs.csv', sep='\t')

# %%
df_logs
# Out:
#                                                   br  \
# 0                           C'hoant am eus da zebriñ
# 1                              Ar wirionez zo gantañ
# 2                            Ar c'hi zo bras awalc'h
# 3  Na vezit ket e gortoz e rofen ar respontoù deoc’h
# 4  Reolennoù ar broponi hag ar yec’hederezh ne oa...
# 5   Paotred Mari-Robin o devoa kaset anezhi d'ar ...
# 6                          E vouezh a oa gouraouliet
# 7                                Setu amañ ur pardon
# 8                                            Echu eo
#
#                                     fr_gpt-3.5-turbo  \
# 0                                      Je veux crier
# 1                             La vérité est avec lui
# 2                        Le chien est toujours grand
# 3   Ne vous attendez pas à ce qu'il vous donne de...
# 4   Les règles de l'élevage et de la santé n'étai...
# 5   Les garçons de Mari-Robin l'avaient emmenée à...
# 6                             Sa voix était étouffée
# ...

# %%
df_res = pd.read_csv('2024-06-09_18:49:56_samples_res.csv', sep='\t')

# %%
df_res
# Out:
#               datetime                   model  mean   std  price  tokens
# 0  2024-06-09_18:49:56           gpt-3.5-turbo  0.91  0.06   0.00    2160
# 1  2024-06-09_18:49:56  gpt-4-turbo-2024-04-09  0.95  0.04   0.01    2142
